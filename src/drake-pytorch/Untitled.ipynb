# %%
% matplotlib inline
# %load_ext autoreload
# %autoreload 2
from __future__ import print_function

# %% [markdown]
# # Testing Costs and Constraints

# %%
import pydrake # Make sure to import pydrake BEFORE torch!
from networks import *
from nn_costs_and_constraints import make_constrained_opt

# %%
kNetConstructor = lambda: FC(2)
dircol = make_constrained_opt(kNetConstructor)
dircol.Solve()
# Out:
# SolutionResult.kSolutionFound
